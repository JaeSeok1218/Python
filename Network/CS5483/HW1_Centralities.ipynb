# %% [markdown]
# <h1 style="font-size:3rem;color:orange;">Centralities</h1>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import networkx as nx

# %%
# Contruct a graph

V = ['a','b','c','d','e','f','g','h','i']

G = nx.Graph()
G.add_nodes_from(V)
G.add_edge('a','b', relation='s')
G.add_edge('a','c', relation='w')
G.add_edge('a','d', relation='s')
G.add_edge('a','e', relation='w')
G.add_edge('a','f', relation='s')
G.add_edge('b','g', relation='w')
G.add_edge('b','i', relation='s')
G.add_edge('e','i', relation='w')
G.add_edge('f','h', relation='s')
G.edges(data=True)
# Out:
# EdgeDataView([('a', 'b', {'relation': 's'}), ('a', 'c', {'relation': 'w'}), ('a', 'd', {'relation': 's'}), ('a', 'e', {'relation': 'w'}), ('a', 'f', {'relation': 's'}), ('b', 'g', {'relation': 'w'}), ('b', 'i', {'relation': 's'}), ('e', 'i', {'relation': 'w'}), ('f', 'h', {'relation': 's'})])

# %%
pos = nx.spring_layout(G) # to draw edge_labels: positioning
nx.draw(G, pos,
       node_color='C1',
       node_size=200,
       with_labels=True)

edge_labels = dict([((n1, n2), d['relation'])
                    for n1, n2, d in G.edges(data=True)]) # make a dictionary; n1-node n2-node d-'relation' here
nx.draw_networkx_edge_labels(G,pos, edge_labels)
plt.show(G)

# %% [markdown]
# ## a. Degree Centrality

# %%
d = nx.degree_centrality(G)

for v in G.nodes():
    print(f"{v:2} {d[v]:.3f}")
    
sort_list = sorted(d.items(), key=lambda x: x[1], reverse=True) 
# key=lambda x:x[1]: lambda function(simple function) sorting by 1st element

color_map = []
for node in G:
    if (node == sort_list[0][0]) or (node== sort_list[1][0]):
        color_map.append('red')
    else: 
        color_map.append('green')
pos = nx.spring_layout(G) # to draw edge_labels: positioning
nx.draw(G, pos,
       node_color=color_map,
       node_size=200,
       with_labels=True)

edge_labels = dict([((n1, n2), d['relation'])
                    for n1, n2, d in G.edges(data=True)]) # make a dictionary; n1-node n2-node d-'relation' here
nx.draw_networkx_edge_labels(G, pos, edge_labels)
plt.show(G)
# Out:
# a  0.625
# b  0.375
# c  0.125
# d  0.125
# e  0.250
# f  0.250
# g  0.125
# h  0.125
# i  0.250

# %% [markdown]
# ## b. Eigenvector Centrality

# %%
centrality = nx.eigenvector_centrality(G)
for v, c in centrality.items():
    print(f"{v:2} {c:.3f}")

sort_list = sorted(centrality.items(), key=lambda x: x[1], reverse=True)

color_map = []
for node in G:
    if (node == sort_list[0][0]) or (node== sort_list[1][0]):
        color_map.append('red')
    else: 
        color_map.append('green')      
nx.draw(G, pos,
       node_color=color_map,
       node_size=200,
       with_labels=True)

edge_labels = dict([((n1, n2), d['relation'])
                    for n1, n2, d in G.edges(data=True)]) # make a dictionary; n1-node n2-node d-'relation' here
nx.draw_networkx_edge_labels(G, pos, edge_labels)
plt.show(G)
# Out:
# a  0.605
# b  0.424
# c  0.238
# d  0.238
# e  0.358
# f  0.281
# g  0.167
# h  0.110
# i  0.307

# %% [markdown]
# ## c. Page Rank Centrality

# %%
centrality = nx.pagerank(G, alpha=0.5, personalization=None, max_iter=100, tol=1e-06, nstart=None, weight='weight', dangling=None)
for v, c in centrality.items():
    print(f"{v:2} {c:.3f}")

sort_list = sorted(centrality.items(), key=lambda x: x[1], reverse=True)

color_map = []
for node in G:
    if (node == sort_list[0][0]) or (node== sort_list[1][0]):
        color_map.append('red')
    else: 
        color_map.append('green')      
nx.draw(G, pos,
       node_color=color_map,
       node_size=200,
       with_labels=True)

edge_labels = dict([((n1, n2), d['relation'])
                    for n1, n2, d in G.edges(data=True)]) # make a dictionary; n1-node n2-node d-'relation' here
nx.draw_networkx_edge_labels(G, pos, edge_labels)
plt.show(G)
# Out:
# a  0.212
# b  0.143
# c  0.077
# d  0.077
# e  0.103
# f  0.119
# g  0.079
# h  0.085
# i  0.105

# %% [markdown]
# ## d. Katz Centrality

# %%
centrality = nx.katz_centrality_numpy(G, alpha=0.2, beta=1.0, normalized=True, weight=None)
for v, c in centrality.items():
    print(f"{v:2} {c:.3f}")

sort_list = sorted(centrality.items(), key=lambda x: x[1], reverse=True)

color_map = []
for node in G:
    if (node == sort_list[0][0]) or (node== sort_list[1][0]):
        color_map.append('red')
    else: 
        color_map.append('green')      
nx.draw(G, pos,
       node_color=color_map,
       node_size=200,
       with_labels=True)

edge_labels = dict([((n1, n2), d['relation'])
                    for n1, n2, d in G.edges(data=True)]) # make a dictionary; n1-node n2-node d-'relation' here
nx.draw_networkx_edge_labels(G, pos, edge_labels)
plt.show(G)
# Out:
# a  0.498
# b  0.391
# c  0.276
# d  0.276
# e  0.340
# f  0.324
# g  0.254
# h  0.241
# i  0.322
