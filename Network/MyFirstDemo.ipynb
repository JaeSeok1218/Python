# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.DiGraph()
G.add_node('Alice')
G.add_node('Bob')
G.add_node('Chuck')
list(G.nodes())
# Out:
# ['Alice', 'Bob', 'Chuck']

# %%
G.add_edge('Alice','Bob')
G.add_edge('Alice','Chuck')
G.add_edge('Bob','Alice')
G.add_edge('Bob','Chuck')
list(G.edges())
# Out:
# [('Alice', 'Bob'), ('Alice', 'Chuck'), ('Bob', 'Alice'), ('Bob', 'Chuck')]

# %%
nx.draw_circular(G,node_color='C0', node_size=2000, with_labels=True)
plt.show()

# %%
positions = dict(OKC=(-97, 35),
                Dallas=(-96,32),
                KansasCity=(-94,39),
                Denver=(-104,39))
positions['OKC']
# Out:
# (-97, 35)

# %%
G = nx.Graph()
G.add_nodes_from(positions)
G.nodes()
# Out:
# NodeView(('OKC', 'Dallas', 'KansasCity', 'Denver'))

# %%
drive_times = {('OKC','Dallas'):3,
              ('OKC','KansasCity'):5,
              ('KansasCity','Denver'):8,
              ('Denver','OKC'):9}

# %%
G.add_edges_from(drive_times)
G.edges()
# Out:
# EdgeView([('OKC', 'Dallas'), ('OKC', 'KansasCity'), ('OKC', 'Denver'), ('KansasCity', 'Denver')])

# %%
nx.draw(G, positions,
       node_color='C1',
       node_shape='s',
       node_size=2500,
       with_labels=True)

nx.draw_networkx_edge_labels(G,positions,
                            edge_labels=drive_times)
plt.show()
