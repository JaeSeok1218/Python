# %%
from bs4 import BeautifulSoup
import csv
import pandas as pd

html_content = """
<tbody role="rowgroup" class="css-aydg0x"><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Mar 1, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">6:32 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,206</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 29, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">7:39 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,315</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 29, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">10:59 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,845</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 29, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">9:17 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,819</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"><span><svg viewBox="0 0 50 50" focusable="false" class="chakra-icon css-10c04ul"><path d="M19.1001 36.2C17.2001 38.1 14.5001 38.4 13.1001 36.9C11.6001 35.4 11.9001 32.7 13.8001 30.9C14.0001 30.7 14.3001 30.5 14.5001 30.3C12.6001 29.7 10.7001 30 9.40006 31.3C9.40006 31.3 6.70006 34.1 7.40006 42.6C7.40006 42.6 15.1001 44 18.7001 40.6C20.0001 39.4 20.3001 37.4 19.7001 35.5C19.5001 35.7 19.3001 35.9 19.1001 36.2Z" fill="currentColor"></path><path d="M42.6999 8.29998L42.5999 7.39998L41.6999 7.29998C41.5999 7.29998 29.9999 5.89998 20.8999 15L15.3999 14.2L8.3999 21.6L15.0999 23.2C14.4999 24.3 13.9999 25.5 13.4999 26.8L13.1999 27.5L22.4999 36.8L23.1999 36.5C24.4999 36 25.6999 35.5 26.7999 34.9L28.3999 41.7L35.7999 34.7L34.9999 29C44.0999 19.9 42.6999 8.39998 42.6999 8.29998ZM23.0999 33.8L16.0999 26.8C22.6999 9.99998 36.4999 9.39998 40.2999 9.59998C40.4999 13.4 39.8999 27.2 23.0999 33.8Z" fill="currentColor"></path><path d="M26.9001 18C25.5001 19.4 25.5001 21.6 26.9001 22.9C28.3001 24.3 30.5001 24.3 31.8001 22.9C33.2001 21.5 33.2001 19.3 31.8001 18C30.5001 16.7 28.3001 16.7 26.9001 18Z" fill="currentColor"></path></svg></span></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 28, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">1:52 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,299</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 27, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">3:05 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,079</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 26, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">3:43 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,900</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 26, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">4:17 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,800</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 25, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">7:10 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,330</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 20, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">7:55 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,755</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 19, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">6:44 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,750</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 17, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">4:22 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,757</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 16, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">3:47 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,654</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 16, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">12:32 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,700</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 13, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">2:11 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,766</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 13, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">7:30 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,700</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 11, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">3:41 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,068</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 6, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">7:52 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,769</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 6, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">8:02 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,634</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 2, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">12:36 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,840</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Feb 2, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">6:35 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,629</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 31, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">1:13 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,800</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 30, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">7:36 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,675</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 29, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">4:12 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,686</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 26, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">2:33 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,850</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 25, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">2:08 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,830</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 23, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">4:37 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,786</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 19, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">8:02 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,800</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 18, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">6:07 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,798</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 18, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">12:02 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,799</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 17, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">10:56 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,281</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 10, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">5:41 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,725</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 6, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">7:37 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,008</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 4, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">9:20 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,850</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 4, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">6:04 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,943</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 3, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">2:21 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,550</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 2, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">6:55 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,825</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Jan 2, 2024</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">8:30 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,913</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 31, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">12:59 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,840</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 31, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">11:34 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,520</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 26, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">6:09 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,750</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 24, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">12:54 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,750</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 22, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">3:31 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,884</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 20, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">8:27 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,700</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 19, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">3:32 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,540</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 18, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">3:45 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,714</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 13, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">1:37 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,416</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 12, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">10:44 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,599</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 12, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">3:20 PM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,338</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 30 0 auto; min-width: 0px; width: 30px;"><p class="chakra-text css-2bkegz"></p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 110 0 auto; min-width: 0px; width: 110px;"><p class="chakra-text css-2bkegz">Dec 11, 2023</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 90 0 auto; min-width: 0px; width: 90px;"><p class="chakra-text css-2bkegz">12:14 AM</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,808</p></p></td></tr></tbody>
"""

soup = BeautifulSoup(html_content, "html.parser")

# %%
items = soup.find_all("p", class_="chakra-text css-2bkegz")
for item in items:
    print(item.text)
# Out:
# Mar 1, 2024
# 6:32 AM
# US M 10.5
# $2,206
#
# Feb 29, 2024
# 7:39 PM
# US M 10.5
# $2,315
#
# Feb 29, 2024
# 10:59 AM
# US M 10.5
# $1,845
#
# Feb 29, 2024
# 9:17 AM
# US M 10.5
# $1,819
#
# Feb 28, 2024
# 1:52 PM
# US M 10.5
# $2,299
#
# Feb 27, 2024
# 3:05 PM
# US M 10.5
# $2,079
#
# Feb 26, 2024
# 3:43 PM
# US M 10.5
# $1,900
#
# Feb 26, 2024
# 4:17 AM
# US M 10.5
# $1,800
#
# Feb 25, 2024
# 7:10 PM
# US M 10.5
# $2,330
#
# Feb 20, 2024
# 7:55 PM
# US M 10.5
# $1,755
#
# Feb 19, 2024
# 6:44 AM
# US M 10.5
# $1,750
#
# Feb 17, 2024
# 4:22 PM
# US M 10.5
# $1,757
#
# Feb 16, 2024
# 3:47 PM
# US M 10.5
# $1,654
#
# Feb 16, 2024
# 12:32 PM
# US M 10.5
# $1,700
#
# Feb 13, 2024
# 2:11 PM
# US M 10.5
# $1,766
#
# Feb 13, 2024
# 7:30 AM
# US M 10.5
# $1,700
#
# Feb 11, 2024
# 3:41 PM
# US M 10.5
# $2,068
#
# Feb 6, 2024
# 7:52 PM
# US M 10.5
# $1,769
#
# Feb 6, 2024
# 8:02 AM
# US M 10.5
# $1,634
#
# Feb 2, 2024
# 12:36 PM
# US M 10.5
# $1,840
#
# Feb 2, 2024
# 6:35 AM
# US M 10.5
# ...

# %%
dates = []
times = []
sizes = []
prices = []

common_diff = 5

for i, item in enumerate(items):
    if i % common_diff == 1:
        dates.append(item.text)
    elif i % common_diff == 2:
        times.append(item.text)
    elif i % common_diff == 3:
        sizes.append(item.text)
    elif i % common_diff == 4:
        prices.append(item.text)
    else:
        pass

# %%
df = pd.DataFrame({
    'Date': dates,
    'Time': times,
    'Size': sizes,
    'Price': prices
})

print(df)

#df.to_csv('Sneakers.csv', index=False)
# Out:
#             Date      Time       Size   Price
# 0    Mar 1, 2024   6:32 AM  US M 10.5  $2,206
# 1   Feb 29, 2024   7:39 PM  US M 10.5  $2,315
# 2   Feb 29, 2024  10:59 AM  US M 10.5  $1,845
# 3   Feb 29, 2024   9:17 AM  US M 10.5  $1,819
# 4   Feb 28, 2024   1:52 PM  US M 10.5  $2,299
# 5   Feb 27, 2024   3:05 PM  US M 10.5  $2,079
# 6   Feb 26, 2024   3:43 PM  US M 10.5  $1,900
# 7   Feb 26, 2024   4:17 AM  US M 10.5  $1,800
# 8   Feb 25, 2024   7:10 PM  US M 10.5  $2,330
# 9   Feb 20, 2024   7:55 PM  US M 10.5  $1,755
# 10  Feb 19, 2024   6:44 AM  US M 10.5  $1,750
# 11  Feb 17, 2024   4:22 PM  US M 10.5  $1,757
# 12  Feb 16, 2024   3:47 PM  US M 10.5  $1,654
# 13  Feb 16, 2024  12:32 PM  US M 10.5  $1,700
# 14  Feb 13, 2024   2:11 PM  US M 10.5  $1,766
# 15  Feb 13, 2024   7:30 AM  US M 10.5  $1,700
# 16  Feb 11, 2024   3:41 PM  US M 10.5  $2,068
# 17   Feb 6, 2024   7:52 PM  US M 10.5  $1,769
# 18   Feb 6, 2024   8:02 AM  US M 10.5  $1,634
# ...

# %%
latex_table = df.to_latex(index=False)

# Print LaTeX table
print(latex_table)
# Out:
# \begin{tabular}{llll}
# \toprule
#         Date &     Time &      Size &  Price \\
# \midrule
#  Mar 1, 2024 &  6:32 AM & US M 10.5 & \$2,206 \\
# Feb 29, 2024 &  7:39 PM & US M 10.5 & \$2,315 \\
# Feb 29, 2024 & 10:59 AM & US M 10.5 & \$1,845 \\
# Feb 29, 2024 &  9:17 AM & US M 10.5 & \$1,819 \\
# Feb 28, 2024 &  1:52 PM & US M 10.5 & \$2,299 \\
# Feb 27, 2024 &  3:05 PM & US M 10.5 & \$2,079 \\
# Feb 26, 2024 &  3:43 PM & US M 10.5 & \$1,900 \\
# Feb 26, 2024 &  4:17 AM & US M 10.5 & \$1,800 \\
# Feb 25, 2024 &  7:10 PM & US M 10.5 & \$2,330 \\
# Feb 20, 2024 &  7:55 PM & US M 10.5 & \$1,755 \\
# Feb 19, 2024 &  6:44 AM & US M 10.5 & \$1,750 \\
# Feb 17, 2024 &  4:22 PM & US M 10.5 & \$1,757 \\
# Feb 16, 2024 &  3:47 PM & US M 10.5 & \$1,654 \\
# Feb 16, 2024 & 12:32 PM & US M 10.5 & \$1,700 \\
# Feb 13, 2024 &  2:11 PM & US M 10.5 & \$1,766 \\
# Feb 13, 2024 &  7:30 AM & US M 10.5 & \$1,700 \\
# Feb 11, 2024 &  3:41 PM & US M 10.5 & \$2,068 \\
# ...

# %%
html_content = """
<tbody role="rowgroup" class="css-aydg0x"><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,902</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,903</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,905</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,950</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,080</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,194</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,237</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,243</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,249</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,267</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,295</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,390</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,400</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,445</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,481</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,500</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,571</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,795</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$2,958</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$9,999</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$12,194</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$15,001</p></p></td></tr></tbody>
"""

soup = BeautifulSoup(html_content, "html.parser")

# %%
items = soup.find_all("p", class_="chakra-text css-2bkegz")
for item in items:
    print(item.text)
# Out:
# 1
# US M 10.5
# $1,902
# 1
# US M 10.5
# $1,903
# 1
# US M 10.5
# $1,905
# 1
# US M 10.5
# $1,950
# 1
# US M 10.5
# $2,080
# 1
# US M 10.5
# $2,194
# 1
# US M 10.5
# $2,237
# 1
# US M 10.5
# $2,243
# 1
# US M 10.5
# $2,249
# 1
# US M 10.5
# $2,267
# 1
# US M 10.5
# $2,295
# 1
# US M 10.5
# $2,390
# 1
# US M 10.5
# $2,400
# 1
# US M 10.5
# $2,445
# 1
# US M 10.5
# $2,481
# 1
# US M 10.5
# $2,500
# 1
# US M 10.5
# $2,571
# 1
# US M 10.5
# $2,795
# 1
# US M 10.5
# $2,958
# 1
# US M 10.5
# $9,999
# 1
# US M 10.5
# $12,194
# 1
# US M 10.5
# $15,001

# %%
quantities = []
sizes = []
prices = []

common_diff = 3

for i, item in enumerate(items):
    if i % common_diff == 0:
        quantities.append(item.text)
    elif i % common_diff == 1:
        sizes.append(item.text)
    else:
        prices.append(item.text)

# %%
df = pd.DataFrame({
    'Quantities': quantities,
    'Size': sizes,
    'Price': prices
})

print(df)
# Out:
#    Quantities       Size    Price
# 0           1  US M 10.5   $1,902
# 1           1  US M 10.5   $1,903
# 2           1  US M 10.5   $1,905
# 3           1  US M 10.5   $1,950
# 4           1  US M 10.5   $2,080
# 5           1  US M 10.5   $2,194
# 6           1  US M 10.5   $2,237
# 7           1  US M 10.5   $2,243
# 8           1  US M 10.5   $2,249
# 9           1  US M 10.5   $2,267
# 10          1  US M 10.5   $2,295
# 11          1  US M 10.5   $2,390
# 12          1  US M 10.5   $2,400
# 13          1  US M 10.5   $2,445
# 14          1  US M 10.5   $2,481
# 15          1  US M 10.5   $2,500
# 16          1  US M 10.5   $2,571
# 17          1  US M 10.5   $2,795
# 18          1  US M 10.5   $2,958
# 19          1  US M 10.5   $9,999
# 20          1  US M 10.5  $12,194
# 21          1  US M 10.5  $15,001

# %%
latex_table = df.to_latex(index=False)

# Print LaTeX table
print(latex_table)
# Out:
# \begin{tabular}{lll}
# \toprule
# Quantities &      Size &   Price \\
# \midrule
#          1 & US M 10.5 &  \$1,902 \\
#          1 & US M 10.5 &  \$1,903 \\
#          1 & US M 10.5 &  \$1,905 \\
#          1 & US M 10.5 &  \$1,950 \\
#          1 & US M 10.5 &  \$2,080 \\
#          1 & US M 10.5 &  \$2,194 \\
#          1 & US M 10.5 &  \$2,237 \\
#          1 & US M 10.5 &  \$2,243 \\
#          1 & US M 10.5 &  \$2,249 \\
#          1 & US M 10.5 &  \$2,267 \\
#          1 & US M 10.5 &  \$2,295 \\
#          1 & US M 10.5 &  \$2,390 \\
#          1 & US M 10.5 &  \$2,400 \\
#          1 & US M 10.5 &  \$2,445 \\
#          1 & US M 10.5 &  \$2,481 \\
#          1 & US M 10.5 &  \$2,500 \\
#          1 & US M 10.5 &  \$2,571 \\
#          1 & US M 10.5 &  \$2,795 \\
#          1 & US M 10.5 &  \$2,958 \\
#          1 & US M 10.5 &  \$9,999 \\
#          1 & US M 10.5 & \$12,194 \\
#          1 & US M 10.5 & \$15,001 \\
# \bottomrule
# \end{tabular}
# ...

# %%
html_content = """
<tbody role="rowgroup" class="css-aydg0x"><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,681</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,680</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,600</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,500</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,455</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,451</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,450</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,400</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,383</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,350</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,320</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,317</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,291</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,245</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,200</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,183</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,171</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,166</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,118</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,088</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,051</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,013</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,011</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,010</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,007</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">2</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$1,000</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$975</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$971</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$950</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$800</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$701</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$700</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$665</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$662</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$653</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$533</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">2</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$500</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$400</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$330</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$284</p></p></td></tr><tr role="row" class="css-153ufkt" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">2</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$243</p></p></td></tr><tr role="row" class="css-cu9nqe" style="display: flex; flex: 1 0 auto; min-width: 0px;"><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 70 0 auto; min-width: 0px; width: 70px;"><p class="chakra-text css-2bkegz">1</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 75 0 auto; min-width: 0px; width: 75px;"><p class="chakra-text css-2bkegz">US M 10.5</p></td><td role="cell" class="css-1po606w" style="box-sizing: border-box; flex: 100 0 auto; min-width: 0px; width: 100px;"><p class="chakra-text css-2bkegz"><p class="chakra-text css-6tf6w0">$150</p></p></td></tr></tbody>"""

# %%
soup = BeautifulSoup(html_content, "html.parser")

# %%
items = soup.find_all("p", class_="chakra-text css-2bkegz")
for item in items:
    print(item.text)
# Out:
# 1
# US M 10.5
# $1,681
# 1
# US M 10.5
# $1,680
# 1
# US M 10.5
# $1,600
# 1
# US M 10.5
# $1,500
# 1
# US M 10.5
# $1,455
# 1
# US M 10.5
# $1,451
# 1
# US M 10.5
# $1,450
# 1
# US M 10.5
# $1,400
# 1
# US M 10.5
# $1,383
# 1
# US M 10.5
# $1,350
# 1
# US M 10.5
# $1,320
# 1
# US M 10.5
# $1,317
# 1
# US M 10.5
# $1,291
# 1
# US M 10.5
# $1,245
# 1
# US M 10.5
# $1,200
# 1
# US M 10.5
# $1,183
# 1
# US M 10.5
# $1,171
# 1
# US M 10.5
# $1,166
# 1
# US M 10.5
# $1,118
# 1
# US M 10.5
# $1,088
# 1
# US M 10.5
# $1,051
# 1
# US M 10.5
# $1,013
# 1
# US M 10.5
# $1,011
# 1
# US M 10.5
# $1,010
# 1
# US M 10.5
# $1,007
# 2
# US M 10.5
# $1,000
# 1
# US M 10.5
# $975
# 1
# US M 10.5
# $971
# 1
# US M 10.5
# $950
# 1
# US M 10.5
# $800
# 1
# US M 10.5
# $701
# 1
# US M 10.5
# $700
# 1
# US M 10.5
# $665
# 1
# US M 10.5
# $662
# 1
# US M 10.5
# $653
# 1
# US M 10.5
# $533
# 2
# US M 10.5
# $500
# 1
# US M 10.5
# $400
# 1
# US M 10.5
# $330
# 1
# US M 10.5
# $284
# 2
# US M 10.5
# $243
# 1
# ...

# %%
quantities = []
sizes = []
prices = []

common_diff = 3

for i, item in enumerate(items):
    if i % common_diff == 0:
        quantities.append(item.text)
    elif i % common_diff == 1:
        sizes.append(item.text)
    else:
        prices.append(item.text)

# %%
df = pd.DataFrame({
    'Quantities': quantities,
    'Size': sizes,
    'Price': prices
})

print(df)
# Out:
#    Quantities       Size   Price
# 0           1  US M 10.5  $1,681
# 1           1  US M 10.5  $1,680
# 2           1  US M 10.5  $1,600
# 3           1  US M 10.5  $1,500
# 4           1  US M 10.5  $1,455
# 5           1  US M 10.5  $1,451
# 6           1  US M 10.5  $1,450
# 7           1  US M 10.5  $1,400
# 8           1  US M 10.5  $1,383
# 9           1  US M 10.5  $1,350
# 10          1  US M 10.5  $1,320
# 11          1  US M 10.5  $1,317
# 12          1  US M 10.5  $1,291
# 13          1  US M 10.5  $1,245
# 14          1  US M 10.5  $1,200
# 15          1  US M 10.5  $1,183
# 16          1  US M 10.5  $1,171
# 17          1  US M 10.5  $1,166
# 18          1  US M 10.5  $1,118
# 19          1  US M 10.5  $1,088
# 20          1  US M 10.5  $1,051
# 21          1  US M 10.5  $1,013
# 22          1  US M 10.5  $1,011
# 23          1  US M 10.5  $1,010
# 24          1  US M 10.5  $1,007
# 25          2  US M 10.5  $1,000
# 26          1  US M 10.5    $975
# ...

# %%
latex_table = df.to_latex(index=False)

# Print LaTeX table
print(latex_table)
# Out:
# \begin{tabular}{lll}
# \toprule
# Quantities &      Size &  Price \\
# \midrule
#          1 & US M 10.5 & \$1,681 \\
#          1 & US M 10.5 & \$1,680 \\
#          1 & US M 10.5 & \$1,600 \\
#          1 & US M 10.5 & \$1,500 \\
#          1 & US M 10.5 & \$1,455 \\
#          1 & US M 10.5 & \$1,451 \\
#          1 & US M 10.5 & \$1,450 \\
#          1 & US M 10.5 & \$1,400 \\
#          1 & US M 10.5 & \$1,383 \\
#          1 & US M 10.5 & \$1,350 \\
#          1 & US M 10.5 & \$1,320 \\
#          1 & US M 10.5 & \$1,317 \\
#          1 & US M 10.5 & \$1,291 \\
#          1 & US M 10.5 & \$1,245 \\
#          1 & US M 10.5 & \$1,200 \\
#          1 & US M 10.5 & \$1,183 \\
#          1 & US M 10.5 & \$1,171 \\
#          1 & US M 10.5 & \$1,166 \\
#          1 & US M 10.5 & \$1,118 \\
#          1 & US M 10.5 & \$1,088 \\
#          1 & US M 10.5 & \$1,051 \\
#          1 & US M 10.5 & \$1,013 \\
#          1 & US M 10.5 & \$1,011 \\
#          1 & US M 10.5 & \$1,010 \\
# ...
